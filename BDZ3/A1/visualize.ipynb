# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
n_corr = pd.read_csv('n_correlation.csv', sep = ';')
n_corr
# Out:
#          n      area  area_diff
# 0      100  0.777771   0.166746
# 1      600  1.134250   0.189732
# 2     1100  0.945699   0.001181
# 3     1600  0.984366   0.039849
# 4     2100  1.087950   0.143436
# ..     ...       ...        ...
# 195  97600  0.945318   0.000801
# 196  98100  0.950807   0.006290
# 197  98600  0.923307   0.021210
# 198  99100  0.926791   0.017726
# 199  99600  0.954351   0.009833
#
# [200 rows x 3 columns]

# %%
plt.plot(n_corr['n'], n_corr['area'])

ax = plt.gca()  
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.title("Predicted area correlation for n",{'family':'serif','color':'blue','size':20})
plt.xlabel("N")
plt.ylabel("predicted area")
# Out:
# Text(0, 0.5, 'predicted area')

# %%
plt.plot(n_corr['n'], n_corr['area_diff'])

ax = plt.gca()  
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['left'].set_position(('data', 0))
ax.spines['bottom'].set_position(('data', 0))

plt.title("Predicted area difference by n",{'family':'serif','color':'blue','size':20})
plt.xlabel("N")
plt.ylabel("difference with correct area")
# Out:
# Text(0, 0.5, 'difference with correct area')

# %%
scale_corr = pd.read_csv('scale_correlation.csv', sep=';')
scale_corr
# Out:
#     scale      area  area_diff
# 0     1.0  0.940607   0.003910
# 1     1.1  0.859772   0.084745
# 2     1.2  0.788473   0.156044
# 3     1.3  0.726401   0.218116
# 4     1.4  0.671539   0.272978
# ..    ...       ...        ...
# 86    9.6  0.100799   0.843718
# 87    9.7  0.096474   0.848043
# 88    9.8  0.092704   0.851813
# 89    9.9  0.095672   0.848846
# 90   10.0  0.093235   0.851282
#
# [91 rows x 3 columns]

# %%
plt.plot(scale_corr['scale'], scale_corr['area'])

ax = plt.gca()  
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.title("Predicted area correlation for scale",{'family':'serif','color':'blue','size':20})
plt.xlabel("Scale")
plt.ylabel("Area correlation")
# Out:
# Text(0, 0.5, 'Scale correlation')

# %%
plt.plot(scale_corr['scale'], scale_corr['area_diff'])

ax = plt.gca()  
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.title("Predicted area difference n for scale",{'family':'serif','color':'blue','size':20})
plt.xlabel("N")
plt.ylabel("Scale correlation")
# Out:
# Text(0, 0.5, 'Scale correlation')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("tested_data.csv", sep=';')
data
# Out:
#          n     array_type sorting_type      time
# 0      500         random        quick     48875
# 1     1000         random        quick    106417
# 2     1500         random        quick    166959
# 3     2000         random        quick    233083
# 4     2500         random        quick    293166
# ..     ...            ...          ...       ...
# 175  13000  almost_sorted        intro  57084709
# 176  13500  almost_sorted        intro  63252500
# 177  14000  almost_sorted        intro  65676750
# 178  14500  almost_sorted        intro  72190500
# 179  15000  almost_sorted        intro  74834458
#
# [180 rows x 4 columns]

# %%
random_arrs = data[data["array_type"] == "random"]
random_arrs.head(10)
# Out:
#       n array_type sorting_type    time
# 0   500     random        quick   48875
# 1  1000     random        quick  106417
# 2  1500     random        quick  166959
# 3  2000     random        quick  233083
# 4  2500     random        quick  293166
# 5  3000     random        quick  362708
# 6  3500     random        quick  430500
# 7  4000     random        quick  507958
# 8  4500     random        quick  577792
# 9  5000     random        quick  637833

# %%
quicks = random_arrs[random_arrs["sorting_type"] == "quick"]
intros = random_arrs[random_arrs["sorting_type"] == "intro"]

# %%
plt.plot(quicks['n'], quicks['time'], label="quick sort")
plt.plot(intros["n"], intros['time'], label="intro sort")

plt.legend()
plt.grid()

ax = plt.gca()  
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.title("Time for sorting random arrays",{'family':'serif','color':'blue','size':20})
plt.xlabel("Lenght of array")
plt.ylabel("nanoseconds")
# Out:
# Text(0, 0.5, 'nanoseconds')

# %%
reversed_arrs = data[data["array_type"] == "reversed"]
reversed_arrs.head(10)
# Out:
#        n array_type sorting_type      time
# 30   500   reversed        quick    408166
# 31  1000   reversed        quick   1618708
# 32  1500   reversed        quick   3561417
# 33  2000   reversed        quick   6322292
# 34  2500   reversed        quick   9859083
# 35  3000   reversed        quick  14216292
# 36  3500   reversed        quick  19382334
# 37  4000   reversed        quick  25213792
# 38  4500   reversed        quick  31946083
# 39  5000   reversed        quick  39356167

# %%
quicks = reversed_arrs[reversed_arrs["sorting_type"] == "quick"]
intros = reversed_arrs[reversed_arrs["sorting_type"] == "intro"]

# %%
plt.plot(quicks['n'], quicks['time'], label="quick sort")
plt.plot(intros["n"], intros['time'], label="intro sort")

plt.legend()
plt.grid()

ax = plt.gca()  
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.title("Time for sorting reversed arrays",{'family':'serif','color':'blue','size':20})
plt.xlabel("Lenght of array")
plt.ylabel("nanoseconds")
# Out:
# Text(0, 0.5, 'nanoseconds')

# %%
almost_arrs = data[data["array_type"] == "almost_sorted"]
almost_arrs.head(10)
# Out:
#        n     array_type sorting_type     time
# 60   500  almost_sorted        quick   401334
# 61  1000  almost_sorted        quick  1038250
# 62  1500  almost_sorted        quick  1494417
# 63  2000  almost_sorted        quick  2566750
# 64  2500  almost_sorted        quick  3582542
# 65  3000  almost_sorted        quick  4201958
# 66  3500  almost_sorted        quick  5790167
# 67  4000  almost_sorted        quick  5999292
# 68  4500  almost_sorted        quick  7826375
# 69  5000  almost_sorted        quick  7855459

# %%
quicks = almost_arrs[almost_arrs["sorting_type"] == "quick"]
intros = almost_arrs[almost_arrs["sorting_type"] == "intro"]

# %%
plt.plot(quicks['n'], quicks['time'], label="quick sort")
plt.plot(intros["n"], intros['time'], label="intro sort")

plt.legend()
plt.grid()

ax = plt.gca()  
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.title("Time for sorting almost sorted arrays",{'family':'serif','color':'blue','size':20})
plt.xlabel("Lenght of array")
plt.ylabel("nanoseconds")
# Out:
# Text(0, 0.5, 'nanoseconds')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("tested_data.csv", sep=';')
data
# Out:
#          n     array_type sorting_type       time
# 0      500         random        quick      48917
# 1     1000         random        quick     107375
# 2     1500         random        quick     164250
# 3     2000         random        quick     227417
# 4     2500         random        quick     294792
# ..     ...            ...          ...        ...
# 175  13000  almost_sorted        intro  829053666
# 176  13500  almost_sorted        intro  831881958
# 177  14000  almost_sorted        intro  865556000
# 178  14500  almost_sorted        intro  901051916
# 179  15000  almost_sorted        intro  905334458
#
# [180 rows x 4 columns]

# %%
random_arrs = data[data["array_type"] == "random"]
random_arrs.head(10)
# Out:
#       n array_type sorting_type    time
# 0   500     random        quick   48917
# 1  1000     random        quick  107375
# 2  1500     random        quick  164250
# 3  2000     random        quick  227417
# 4  2500     random        quick  294792
# 5  3000     random        quick  358083
# 6  3500     random        quick  425375
# 7  4000     random        quick  494833
# 8  4500     random        quick  561291
# 9  5000     random        quick  642459

# %%
quicks = random_arrs[random_arrs["sorting_type"] == "quick"]
intros = random_arrs[random_arrs["sorting_type"] == "intro"]

# %%
plt.plot(quicks['n'], quicks['time'], label="quick sort")
plt.plot(intros["n"], intros['time'], label="intro sort")

plt.legend()
plt.grid()

ax = plt.gca()  
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.title("Time for sorting random arrays",{'family':'serif','color':'blue','size':20})
plt.xlabel("Lenght of array")
plt.ylabel("nanoseconds")
# Out:
# Text(0, 0.5, 'nanoseconds')

# %%
reversed_arrs = data[data["array_type"] == "reversed"]
reversed_arrs.head(10)
# Out:
#        n array_type sorting_type      time
# 30   500   reversed        quick    405584
# 31  1000   reversed        quick   1593500
# 32  1500   reversed        quick   3570334
# 33  2000   reversed        quick   6322708
# 34  2500   reversed        quick   9866458
# 35  3000   reversed        quick  14211750
# 36  3500   reversed        quick  19435000
# 37  4000   reversed        quick  25617917
# 38  4500   reversed        quick  32359708
# 39  5000   reversed        quick  41014000

# %%
quicks = reversed_arrs[reversed_arrs["sorting_type"] == "quick"]
intros = reversed_arrs[reversed_arrs["sorting_type"] == "intro"]

# %%
plt.plot(quicks['n'], quicks['time'], label="quick sort")
plt.plot(intros["n"], intros['time'], label="intro sort")

plt.legend()
plt.grid()

ax = plt.gca()  
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.title("Time for sorting reversed arrays",{'family':'serif','color':'blue','size':20})
plt.xlabel("Lenght of array")
plt.ylabel("nanoseconds")
# Out:
# Text(0, 0.5, 'nanoseconds')
